# %% [markdown]
# ## Exercises - Pandas Data Frames
#
# Here are some of the Exercises related to Pandas.
# * Create Pandas Data Frames using Schema
# * Get all the orders which belong to the month of 2013 August
# * Get all the orders which belong to the months of August, September and October in 2013.
# * Get count of orders by status for the month of 2014 January
# * Get all the records from orders where there are no corresponding records in order_items
# * Get all the customers who have not placed any orders
# * Get the revenue by status

# %% [markdown]
# ### Exercise 1 - Create Pandas Data Frames using Schema
#
# Create Pandas Data Frame for orders, order_items and customers. Make sure to use **schema/retail_db/retail.json** to get the column names.

# %%
import os
import json
import csv
import pandas as pd

def get_df(base_folder, data_set_name, schema_file):
    file_names = os.listdir(f'{base_folder}/{data_set_name}')
    retail_schemas = json.load(open(schema_file))
    columns = list(map(lambda col: col['column_name'], retail_schemas[data_set_name]))
    data = []
    for file_name in file_names:
        file_path = f'{base_folder}/{data_set_name}/{file_name}'
        raw_data = open(file_path)
        data += list(raw_data)
    return pd.DataFrame(map(lambda rec: rec.split(','), data), columns=columns)

# %%
orders = get_df('D:/BIGDATA_LEARN/bigdata-learn/data/retail_db', 'orders', 'schemas/retail_db/retail.json')

# %%
order_items = get_df('D:/BIGDATA_LEARN/bigdata-learn/data/retail_db', 'order_items', 'schemas/retail_db/retail.json')

# %%
customers = get_df('D:/BIGDATA_LEARN/bigdata-learn/data/retail_db', 'customers', 'schemas/retail_db/retail.json')

# %%
orders.head()
# Out:
#   order_id             order_date order_customer_id       order_status
# 0        1  2013-07-25 00:00:00.0             11599           CLOSED\n
# 1        2  2013-07-25 00:00:00.0               256  PENDING_PAYMENT\n
# 2        3  2013-07-25 00:00:00.0             12111         COMPLETE\n
# 3        4  2013-07-25 00:00:00.0              8827           CLOSED\n
# 4        5  2013-07-25 00:00:00.0             11318         COMPLETE\n

# %%
customers.head()
# Out:
#   customer_id customer_fname customer_lname customer_email customer_password  \
# 0           1        Richard      Hernandez      XXXXXXXXX         XXXXXXXXX
# 1           2           Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2           3            Ann          Smith      XXXXXXXXX         XXXXXXXXX
# 3           4           Mary          Jones      XXXXXXXXX         XXXXXXXXX
# 4           5         Robert         Hudson      XXXXXXXXX         XXXXXXXXX
#
#             customer_street customer_city customer_state customer_zipcode
# 0        6303 Heather Plaza   Brownsville             TX          78521\n
# 1   9526 Noble Embers Ridge     Littleton             CO          80126\n
# 2    3422 Blue Pioneer Bend        Caguas             PR          00725\n
# 3        8324 Little Common    San Marcos             CA          92069\n
# 4  "10 Crystal River Mall "        Caguas             PR          00725\n

# %% [markdown]
# ### Get all the orders which belong to the month of 2013 August

# %%
orders[orders['order_date'].str[:7]=='2013-08']
# Out:
#       order_id             order_date order_customer_id       order_status
# 1296      1297  2013-08-01 00:00:00.0             11607         COMPLETE\n
# 1297      1298  2013-08-01 00:00:00.0              5105           CLOSED\n
# 1298      1299  2013-08-01 00:00:00.0              7802         COMPLETE\n
# 1299      1300  2013-08-01 00:00:00.0               553  PENDING_PAYMENT\n
# 1300      1301  2013-08-01 00:00:00.0              1604  PENDING_PAYMENT\n
# ...        ...                    ...               ...                ...
# 68705    68706  2013-08-20 00:00:00.0               130         COMPLETE\n
# 68706    68707  2013-08-23 00:00:00.0             11730         COMPLETE\n
# 68707    68708  2013-08-26 00:00:00.0              8852          ON_HOLD\n
# 68708    68709  2013-08-30 00:00:00.0              4756         COMPLETE\n
# 68709    68710  2013-08-31 00:00:00.0              9685         COMPLETE\n
#
# [5680 rows x 4 columns]

# %% [markdown]
# ### Get all the orders which belong to the months of August, September and October in 2013.

# %%
orders[orders['order_date'].str[:7].isin(('2013-08','2013-09','2013-10'))]
# Out:
#       order_id             order_date order_customer_id       order_status
# 1296      1297  2013-08-01 00:00:00.0             11607         COMPLETE\n
# 1297      1298  2013-08-01 00:00:00.0              5105           CLOSED\n
# 1298      1299  2013-08-01 00:00:00.0              7802         COMPLETE\n
# 1299      1300  2013-08-01 00:00:00.0               553  PENDING_PAYMENT\n
# 1300      1301  2013-08-01 00:00:00.0              1604  PENDING_PAYMENT\n
# ...        ...                    ...               ...                ...
# 68737    68738  2013-10-27 00:00:00.0              1100         COMPLETE\n
# 68738    68739  2013-10-28 00:00:00.0              2528          PENDING\n
# 68739    68740  2013-10-29 00:00:00.0             10691          ON_HOLD\n
# 68740    68741  2013-10-30 00:00:00.0              5974  PENDING_PAYMENT\n
# 68741    68742  2013-10-31 00:00:00.0               197         COMPLETE\n
#
# [16856 rows x 4 columns]

# %% [markdown]
# ### Get count of orders by status for the month of 2014 January

# %%
orders[orders['order_date'].str.slice(0,7)=='2014-01'].shape[0]
# Out:
# 5908

# %% [markdown]
# ### Get all the records from orders where there are no corresponding records in order_items

# %%
orders.set_index('order_id'). \
    join(order_items.set_index('order_item_order_id'))
# Out:
#                  order_date order_customer_id       order_status  \
# 1     2013-07-25 00:00:00.0             11599           CLOSED\n
# 10    2013-07-25 00:00:00.0              5648  PENDING_PAYMENT\n
# 10    2013-07-25 00:00:00.0              5648  PENDING_PAYMENT\n
# 10    2013-07-25 00:00:00.0              5648  PENDING_PAYMENT\n
# 10    2013-07-25 00:00:00.0              5648  PENDING_PAYMENT\n
# ...                     ...               ...                ...
# 9998  2013-09-25 00:00:00.0              9419          PENDING\n
# 9998  2013-09-25 00:00:00.0              9419          PENDING\n
# 9999  2013-09-25 00:00:00.0              1185           CLOSED\n
# 9999  2013-09-25 00:00:00.0              1185           CLOSED\n
# 9999  2013-09-25 00:00:00.0              1185           CLOSED\n
#
#      order_item_id order_item_product_id order_item_quantity  \
# 1                1                   957                   1
# 10              24                  1073                   1
# 10              25                  1014                   2
# 10              26                   403                   1
# 10              27                   917                   1
# ...            ...                   ...                 ...
# 9998         24970                   278                   1
# 9998         24971                   627                   1
# 9999         24972                   627                   3
# 9999         24973                   365                   5
# 9999         24974                  1014                   1
#
#      order_item_subtotal order_item_product_price
# 1                 299.98                 299.98\n
# 10                199.99                 199.99\n
# 10                 99.96                  49.98\n
# 10                129.99                 129.99\n
# 10                 21.99                  21.99\n
# ...                  ...                      ...
# 9998               44.99                  44.99\n
# 9998               39.99                  39.99\n
# 9999              119.97                  39.99\n
# 9999              299.95                  59.99\n
# 9999               49.98                  49.98\n
#
# [183650 rows x 8 columns]

# %%
orders.set_index('order_id'). \
    join(order_items.set_index('order_item_order_id')). \
    query('order_item_id.isna()')
# Out:
#                   order_date order_customer_id       order_status  \
# 10015  2013-09-25 00:00:00.0              3112         COMPLETE\n
# 10016  2013-09-25 00:00:00.0              1214       PROCESSING\n
# 10022  2013-09-25 00:00:00.0              2697  PENDING_PAYMENT\n
# 10031  2013-09-25 00:00:00.0              9968         COMPLETE\n
# 10035  2013-09-25 00:00:00.0              2570  PENDING_PAYMENT\n
# ...                      ...               ...                ...
# 9978   2013-09-25 00:00:00.0              3100         CANCELED\n
# 9980   2013-09-25 00:00:00.0              8261  PENDING_PAYMENT\n
# 9982   2013-09-25 00:00:00.0              4860         COMPLETE\n
# 9994   2013-09-25 00:00:00.0              9585  PENDING_PAYMENT\n
# 9996   2013-09-25 00:00:00.0             11839          PENDING\n
#
#       order_item_id order_item_product_id order_item_quantity  \
# 10015           NaN                   NaN                 NaN
# 10016           NaN                   NaN                 NaN
# 10022           NaN                   NaN                 NaN
# 10031           NaN                   NaN                 NaN
# 10035           NaN                   NaN                 NaN
# ...             ...                   ...                 ...
# 9978            NaN                   NaN                 NaN
# 9980            NaN                   NaN                 NaN
# 9982            NaN                   NaN                 NaN
# 9994            NaN                   NaN                 NaN
# 9996            NaN                   NaN                 NaN
#
#       order_item_subtotal order_item_product_price
# 10015                 NaN                      NaN
# 10016                 NaN                      NaN
# 10022                 NaN                      NaN
# 10031                 NaN                      NaN
# 10035                 NaN                      NaN
# ...                   ...                      ...
# 9978                  NaN                      NaN
# 9980                  NaN                      NaN
# 9982                  NaN                      NaN
# 9994                  NaN                      NaN
# 9996                  NaN                      NaN
#
# [11452 rows x 8 columns]

# %%
orders_joined = orders.set_index('order_id'). \
    join(order_items.set_index('order_item_order_id'))

# %%
orders_joined[orders_joined['order_item_id'].isna()]
# Out:
#                   order_date order_customer_id       order_status  \
# 10015  2013-09-25 00:00:00.0              3112         COMPLETE\n
# 10016  2013-09-25 00:00:00.0              1214       PROCESSING\n
# 10022  2013-09-25 00:00:00.0              2697  PENDING_PAYMENT\n
# 10031  2013-09-25 00:00:00.0              9968         COMPLETE\n
# 10035  2013-09-25 00:00:00.0              2570  PENDING_PAYMENT\n
# ...                      ...               ...                ...
# 9978   2013-09-25 00:00:00.0              3100         CANCELED\n
# 9980   2013-09-25 00:00:00.0              8261  PENDING_PAYMENT\n
# 9982   2013-09-25 00:00:00.0              4860         COMPLETE\n
# 9994   2013-09-25 00:00:00.0              9585  PENDING_PAYMENT\n
# 9996   2013-09-25 00:00:00.0             11839          PENDING\n
#
#       order_item_id order_item_product_id order_item_quantity  \
# 10015           NaN                   NaN                 NaN
# 10016           NaN                   NaN                 NaN
# 10022           NaN                   NaN                 NaN
# 10031           NaN                   NaN                 NaN
# 10035           NaN                   NaN                 NaN
# ...             ...                   ...                 ...
# 9978            NaN                   NaN                 NaN
# 9980            NaN                   NaN                 NaN
# 9982            NaN                   NaN                 NaN
# 9994            NaN                   NaN                 NaN
# 9996            NaN                   NaN                 NaN
#
#       order_item_subtotal order_item_product_price
# 10015                 NaN                      NaN
# 10016                 NaN                      NaN
# 10022                 NaN                      NaN
# 10031                 NaN                      NaN
# 10035                 NaN                      NaN
# ...                   ...                      ...
# 9978                  NaN                      NaN
# 9980                  NaN                      NaN
# 9982                  NaN                      NaN
# 9994                  NaN                      NaN
# 9996                  NaN                      NaN
#
# [11452 rows x 8 columns]

# %% [markdown]
# ### Get all the customers who have not placed any orders

# %%
customers.set_index('customer_id'). \
    join(orders.set_index('order_customer_id')). \
    query('order_id.isna()')
# Out:
#       customer_fname customer_lname customer_email customer_password  \
# 10060           Mary           Shaw      XXXXXXXXX         XXXXXXXXX
# 10330           Mary          Smith      XXXXXXXXX         XXXXXXXXX
# 10439           Emma          Smith      XXXXXXXXX         XXXXXXXXX
# 10913           Mary       Williams      XXXXXXXXX         XXXXXXXXX
# 10958           Joan          Smith      XXXXXXXXX         XXXXXXXXX
# 1187         Dorothy        Vazquez      XXXXXXXXX         XXXXXXXXX
# 12175         Amanda          Smith      XXXXXXXXX         XXXXXXXXX
# 12190           Mary          Smith      XXXXXXXXX         XXXXXXXXX
# 12392           Alan           Wolf      XXXXXXXXX         XXXXXXXXX
# 1481           Grace          Smith      XXXXXXXXX         XXXXXXXXX
# 1808          Albert        Ellison      XXXXXXXXX         XXXXXXXXX
# 2073           Donna       Stephens      XXXXXXXXX         XXXXXXXXX
# 2096            Jose         Tanner      XXXXXXXXX         XXXXXXXXX
# 219             Mary        Harrell      XXXXXXXXX         XXXXXXXXX
# 2450           James          Smith      XXXXXXXXX         XXXXXXXXX
# 339             Mary         Greene      XXXXXXXXX         XXXXXXXXX
# 4555            Mary          Smith      XXXXXXXXX         XXXXXXXXX
# 469            Randy          Smith      XXXXXXXXX         XXXXXXXXX
# 4927         Carolyn          Green      XXXXXXXXX         XXXXXXXXX
# 6072         Stephen          Smith      XXXXXXXXX         XXXXXXXXX
# 6613          Ashley          Smith      XXXXXXXXX         XXXXXXXXX
# 7011           Kevin          Smith      XXXXXXXXX         XXXXXXXXX
# 7552            Carl          Smith      XXXXXXXXX         XXXXXXXXX
# 8243            Gary         Walker      XXXXXXXXX         XXXXXXXXX
# 8343            Mary         Bolton      XXXXXXXXX         XXXXXXXXX
# 8575            Mary        Mueller      XXXXXXXXX         XXXXXXXXX
# 8778            Mary          Smith      XXXXXXXXX         XXXXXXXXX
# 8882         Kenneth          Smith      XXXXXXXXX         XXXXXXXXX
# 9060         Matthew          Patel      XXXXXXXXX         XXXXXXXXX
# 9315            Mary          Lewis      XXXXXXXXX         XXXXXXXXX
#
#                     customer_street         customer_city customer_state  \
# 10060    4645 Fallen Timber By-pass                Caguas             PR
# 10330      3410 Lazy Shadow Pathway              Hamilton             OH
# 10439      1465 Clear Elk Diversion                Caguas             PR
# 10913       9113 Grand Hills Parade              San Jose             CA
# 10958       8771 Middle Quail Heath           Los Angeles             CA
# 1187            363 Green Goose Run               Danbury             CT
# 12175  3729 Cinder Grove Concession             Tonawanda             NY
# 12190      4462 Little Lagoon Route                 Tempe             AZ
# 12392    6470 Fallen Barn Autoroute             Santa Ana             CA
# 1481           2171 Clear Lake Isle                Caguas             PR
# 1808              9795 Heather Wynd              Billings             MT
# 2073              9792 Cozy Corners             Sunnyvale             CA
# 2096       8976 Old Hickory Landing                 Bronx             NY
# 219     9016 Foggy Robin Expressway                Denver             CO
# 2450        4063 Little Creek Court                Newark             DE
# 339                 4271 Hazy Close            Long Beach             CA
# 4555           5455 Red Lagoon Maze                Caguas             PR
# 469           252 Golden Goose Loop   South San Francisco             CA
# 4927         7550 Sleepy View Court                Caguas             PR
# 6072        849 Noble Apple Private                Malden             MA
# 6613        9847 Dusty Horse Corner                Caguas             PR
# 7011   1915 Thunder Hickory Freeway             Wyandotte             MI
# 7552               9966 Cinder Loop                Howell             MI
# 8243         2447 Stony Barn Street              New York             NY
# 8343              7302 Sunny Valley                Caguas             PR
# 8575      9714 Emerald Bear Lookout                Caguas             PR
# 8778       4015 Tawny Rise Crescent                Caguas             PR
# 8882            6754 Iron Leaf Line               Hickory             NC
# 9060        7190 Silver Horse Glade             Henderson             NV
# 9315        2993 Burning Dale Farms  North Richland Hills             TX
#
#       customer_zipcode order_id order_date order_status
# 10060          00725\n      NaN        NaN          NaN
# 10330          45013\n      NaN        NaN          NaN
# 10439          00725\n      NaN        NaN          NaN
# 10913          95123\n      NaN        NaN          NaN
# 10958          90024\n      NaN        NaN          NaN
# 1187           06810\n      NaN        NaN          NaN
# 12175          14150\n      NaN        NaN          NaN
# 12190          85283\n      NaN        NaN          NaN
# 12392          92704\n      NaN        NaN          NaN
# 1481           00725\n      NaN        NaN          NaN
# 1808           59102\n      NaN        NaN          NaN
# 2073           94087\n      NaN        NaN          NaN
# 2096           10467\n      NaN        NaN          NaN
# 219            80219\n      NaN        NaN          NaN
# 2450           19702\n      NaN        NaN          NaN
# 339            90805\n      NaN        NaN          NaN
# 4555           00725\n      NaN        NaN          NaN
# 469            94080\n      NaN        NaN          NaN
# 4927           00725\n      NaN        NaN          NaN
# 6072           02148\n      NaN        NaN          NaN
# 6613           00725\n      NaN        NaN          NaN
# 7011           48192\n      NaN        NaN          NaN
# 7552           48843\n      NaN        NaN          NaN
# 8243           10128\n      NaN        NaN          NaN
# 8343           00725\n      NaN        NaN          NaN
# 8575           00725\n      NaN        NaN          NaN
# 8778           00725\n      NaN        NaN          NaN
# 8882           28601\n      NaN        NaN          NaN
# 9060           89014\n      NaN        NaN          NaN
# 9315           76180\n      NaN        NaN          NaN

# %% [markdown]
# ### Get the revenue by status

# %%
orders.head()
# Out:
#   order_id             order_date order_customer_id       order_status
# 0        1  2013-07-25 00:00:00.0             11599           CLOSED\n
# 1        2  2013-07-25 00:00:00.0               256  PENDING_PAYMENT\n
# 2        3  2013-07-25 00:00:00.0             12111         COMPLETE\n
# 3        4  2013-07-25 00:00:00.0              8827           CLOSED\n
# 4        5  2013-07-25 00:00:00.0             11318         COMPLETE\n

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172198 entries, 0 to 172197
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_item_id             172198 non-null  object
#  1   order_item_order_id       172198 non-null  object
#  2   order_item_product_id     172198 non-null  object
#  3   order_item_quantity       172198 non-null  object
#  4   order_item_subtotal       172198 non-null  object
#  5   order_item_product_price  172198 non-null  object
# dtypes: object(6)
# memory usage: 7.9+ MB

# %%
order_items['total'] = order_items['order_item_subtotal'].astype(float)

# %%
orders.set_index('order_id').join(order_items.set_index('order_item_order_id'),how='inner').groupby('order_status')['total'].sum()
# Out:
# order_status
# CANCELED\n             696030.99
# CLOSED\n              3736048.79
# COMPLETE\n           11276933.69
# ON_HOLD\n             1864731.24
# PAYMENT_REVIEW\n       357841.45
# PENDING\n             3851881.28
# PENDING_PAYMENT\n     7581671.05
# PROCESSING\n          4190636.76
# SUSPECTED_FRAUD\n      766844.68
# Name: total, dtype: float64
