# %% [markdown]
# https://kaizen.itversity.com/solutions-sql-analytics-or-windowing-functions-using-postgresql/

# %%
# %load_ext sql

# %%
# %env DATABASE_URL=postgresql://deepan:DB_PASSWORD@localhost:5432/itversity_hr_db
# Out:
# env: DATABASE_URL=postgresql://deepan:DB_PASSWORD@localhost:5432/itversity_hr_db

# %%
# %%sql
#
# SELECT * FROM departments
# ORDER BY manager_id NULLS LAST
# LIMIT 10
# Out:
# 10 rows affected.
# [(90, 'Executive', 100, 1700),
#  (60, 'IT', 103, 1400),
#  (100, 'Finance', 108, 1700),
#  (30, 'Purchasing', 114, 1700),
#  (50, 'Shipping', 121, 1500),
#  (80, 'Sales', 145, 2500),
#  (10, 'Administration', 200, 1700),
#  (20, 'Marketing', 201, 1800),
#  (40, 'Human Resources', 203, 2400),
#  (70, 'Public Relations', 204, 2700)]

# %% [markdown]
# ### problem 1

# %%
# %%sql
#
# SELECT employee_id, department_name, salary, avg_salary_expense
# FROM employees e1
# INNER JOIN (
#     SELECT department_id, round(avg(salary)::numeric, 2) as avg_salary_expense
#     FROM employees GROUP BY department_id
#     ) e2 on e1.department_id=e2.department_id
# INNER JOIN departments d on d.department_id=e1.department_id
# WHERE e1.salary>e2.avg_salary_expense ORDER BY d.department_id, salary DESC;
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_hr_db
# 38 rows affected.
# [(201, 'Marketing', Decimal('13000.00'), Decimal('9500.00')),
#  (114, 'Purchasing', Decimal('11000.00'), Decimal('4150.00')),
#  (121, 'Shipping', Decimal('8200.00'), Decimal('3475.56')),
#  (120, 'Shipping', Decimal('8000.00'), Decimal('3475.56')),
#  (122, 'Shipping', Decimal('7900.00'), Decimal('3475.56')),
#  (123, 'Shipping', Decimal('6500.00'), Decimal('3475.56')),
#  (124, 'Shipping', Decimal('5800.00'), Decimal('3475.56')),
#  (184, 'Shipping', Decimal('4200.00'), Decimal('3475.56')),
#  (185, 'Shipping', Decimal('4100.00'), Decimal('3475.56')),
#  (192, 'Shipping', Decimal('4000.00'), Decimal('3475.56')),
#  (193, 'Shipping', Decimal('3900.00'), Decimal('3475.56')),
#  (188, 'Shipping', Decimal('3800.00'), Decimal('3475.56')),
#  (189, 'Shipping', Decimal('3600.00'), Decimal('3475.56')),
#  (137, 'Shipping', Decimal('3600.00'), Decimal('3475.56')),
#  (141, 'Shipping', Decimal('3500.00'), Decimal('3475.56')),
#  (103, 'IT', Decimal('9000.00'), Decimal('5760.00')),
#  (104, 'IT', Decimal('6000.00'), Decimal('5760.00')),
#  (145, 'Sales', Decimal('14000.00'), Decimal('8955.88')),
#  (146, 'Sales', Decimal('13500.00'), Decimal('8955.88')),
#  (147, 'Sales', Decimal('12000.00'), Decimal('8955.88')),
#  (168, 'Sales', Decimal('11500.00'), Decimal('8955.88')),
#  (174, 'Sales', Decimal('11000.00'), Decimal('8955.88')),
#  (148, 'Sales', Decimal('11000.00'), Decimal('8955.88')),
#  (149, 'Sales', Decimal('10500.00'), Decimal('8955.88')),
#  (162, 'Sales', Decimal('10500.00'), Decimal('8955.88')),
#  (156, 'Sales', Decimal('10000.00'), Decimal('8955.88')),
#  (169, 'Sales', Decimal('10000.00'), Decimal('8955.88')),
#  (150, 'Sales', Decimal('10000.00'), Decimal('8955.88')),
#  (170, 'Sales', Decimal('9600.00'), Decimal('8955.88')),
#  (163, 'Sales', Decimal('9500.00'), Decimal('8955.88')),
#  (151, 'Sales', Decimal('9500.00'), Decimal('8955.88')),
#  (157, 'Sales', Decimal('9500.00'), Decimal('8955.88')),
#  (152, 'Sales', Decimal('9000.00'), Decimal('8955.88')),
#  (158, 'Sales', Decimal('9000.00'), Decimal('8955.88')),
#  (100, 'Executive', Decimal('24000.00'), Decimal('19333.33')),
#  (108, 'Finance', Decimal('12000.00'), Decimal('8600.00')),
#  (109, 'Finance', Decimal('9000.00'), Decimal('8600.00')),
#  (205, 'Accounting', Decimal('12000.00'), Decimal('10150.00'))]

# %%
# %%sql
#
# SELECT t.* FROM (
#     SELECT employee_id, department_name, salary,
#     round(avg(salary) OVER (PARTITION BY e.department_id)::numeric, 2) AS avg_salary_expense
#     FROM employees e INNER JOIN departments d
#     ON e.department_id=d.department_id
# ) t WHERE t.avg_salary_expense<t.salary;
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_hr_db
# 38 rows affected.
# [(201, 'Marketing', Decimal('13000.00'), Decimal('9500.00')),
#  (114, 'Purchasing', Decimal('11000.00'), Decimal('4150.00')),
#  (184, 'Shipping', Decimal('4200.00'), Decimal('3475.56')),
#  (185, 'Shipping', Decimal('4100.00'), Decimal('3475.56')),
#  (188, 'Shipping', Decimal('3800.00'), Decimal('3475.56')),
#  (189, 'Shipping', Decimal('3600.00'), Decimal('3475.56')),
#  (192, 'Shipping', Decimal('4000.00'), Decimal('3475.56')),
#  (193, 'Shipping', Decimal('3900.00'), Decimal('3475.56')),
#  (141, 'Shipping', Decimal('3500.00'), Decimal('3475.56')),
#  (137, 'Shipping', Decimal('3600.00'), Decimal('3475.56')),
#  (120, 'Shipping', Decimal('8000.00'), Decimal('3475.56')),
#  (121, 'Shipping', Decimal('8200.00'), Decimal('3475.56')),
#  (122, 'Shipping', Decimal('7900.00'), Decimal('3475.56')),
#  (123, 'Shipping', Decimal('6500.00'), Decimal('3475.56')),
#  (124, 'Shipping', Decimal('5800.00'), Decimal('3475.56')),
#  (104, 'IT', Decimal('6000.00'), Decimal('5760.00')),
#  (103, 'IT', Decimal('9000.00'), Decimal('5760.00')),
#  (145, 'Sales', Decimal('14000.00'), Decimal('8955.88')),
#  (146, 'Sales', Decimal('13500.00'), Decimal('8955.88')),
#  (147, 'Sales', Decimal('12000.00'), Decimal('8955.88')),
#  (148, 'Sales', Decimal('11000.00'), Decimal('8955.88')),
#  (149, 'Sales', Decimal('10500.00'), Decimal('8955.88')),
#  (150, 'Sales', Decimal('10000.00'), Decimal('8955.88')),
#  (151, 'Sales', Decimal('9500.00'), Decimal('8955.88')),
#  (152, 'Sales', Decimal('9000.00'), Decimal('8955.88')),
#  (156, 'Sales', Decimal('10000.00'), Decimal('8955.88')),
#  (157, 'Sales', Decimal('9500.00'), Decimal('8955.88')),
#  (158, 'Sales', Decimal('9000.00'), Decimal('8955.88')),
#  (162, 'Sales', Decimal('10500.00'), Decimal('8955.88')),
#  (163, 'Sales', Decimal('9500.00'), Decimal('8955.88')),
#  (168, 'Sales', Decimal('11500.00'), Decimal('8955.88')),
#  (169, 'Sales', Decimal('10000.00'), Decimal('8955.88')),
#  (170, 'Sales', Decimal('9600.00'), Decimal('8955.88')),
#  (174, 'Sales', Decimal('11000.00'), Decimal('8955.88')),
#  (100, 'Executive', Decimal('24000.00'), Decimal('19333.33')),
#  (108, 'Finance', Decimal('12000.00'), Decimal('8600.00')),
#  (109, 'Finance', Decimal('9000.00'), Decimal('8600.00')),
#  (205, 'Accounting', Decimal('12000.00'), Decimal('10150.00'))]

# %%
# %%sql
#
# -- solution without avg salary in the output
#
# SELECT employee_id, department_id, salary FROM employees e1
# WHERE salary>(
#     SELECT avg(salary) from employees e2
#     WHERE e1.department_id=e2.department_id
# ) ORDER BY department_id
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_hr_db
# 38 rows affected.
# [(201, 20, Decimal('13000.00')),
#  (114, 30, Decimal('11000.00')),
#  (192, 50, Decimal('4000.00')),
#  (193, 50, Decimal('3900.00')),
#  (120, 50, Decimal('8000.00')),
#  (121, 50, Decimal('8200.00')),
#  (122, 50, Decimal('7900.00')),
#  (123, 50, Decimal('6500.00')),
#  (124, 50, Decimal('5800.00')),
#  (137, 50, Decimal('3600.00')),
#  (141, 50, Decimal('3500.00')),
#  (184, 50, Decimal('4200.00')),
#  (185, 50, Decimal('4100.00')),
#  (188, 50, Decimal('3800.00')),
#  (189, 50, Decimal('3600.00')),
#  (103, 60, Decimal('9000.00')),
#  (104, 60, Decimal('6000.00')),
#  (149, 80, Decimal('10500.00')),
#  (150, 80, Decimal('10000.00')),
#  (151, 80, Decimal('9500.00')),
#  (152, 80, Decimal('9000.00')),
#  (156, 80, Decimal('10000.00')),
#  (157, 80, Decimal('9500.00')),
#  (158, 80, Decimal('9000.00')),
#  (162, 80, Decimal('10500.00')),
#  (163, 80, Decimal('9500.00')),
#  (168, 80, Decimal('11500.00')),
#  (169, 80, Decimal('10000.00')),
#  (170, 80, Decimal('9600.00')),
#  (174, 80, Decimal('11000.00')),
#  (145, 80, Decimal('14000.00')),
#  (147, 80, Decimal('12000.00')),
#  (146, 80, Decimal('13500.00')),
#  (148, 80, Decimal('11000.00')),
#  (100, 90, Decimal('24000.00')),
#  (109, 100, Decimal('9000.00')),
#  (108, 100, Decimal('12000.00')),
#  (205, 110, Decimal('12000.00'))]

# %% [markdown]
# solution from itversity

# %%
# %%sql
#
# -- similar to our 2nd solution
#
# SELECT e.employee_id,
#     e.department_name,
#     e.salary,
#     e.avg_salary_expense
# FROM (
#     SELECT e.employee_id,
#         e.department_id,
#         d.department_name,
#         e.salary,
#         round(avg(e.salary) OVER (PARTITION BY e.department_id), 2) AS avg_salary_expense
#     FROM employees AS e
#         JOIN departments AS d
#             ON e.department_id = d.department_id
# ) AS e
# WHERE e.salary > e.avg_salary_expense
# ORDER BY e.department_id,
#     e.salary DESC

# %% [markdown]
# ### Problem 2

# %%
# %%sql
#
# SELECT employee_id, department_name, salary,
#     sum(salary) OVER (PARTITION BY e.department_id ORDER BY e.salary
#     ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW
#     ) AS cum_salary_expense FROM employees e INNER JOIN departments d
#     ON e.department_id=d.department_id
# WHERE department_name IN ('Finance','IT')
# ORDER BY department_name, salary;
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_hr_db
# 11 rows affected.
# [(113, 'Finance', Decimal('6900.00'), Decimal('6900.00')),
#  (111, 'Finance', Decimal('7700.00'), Decimal('14600.00')),
#  (112, 'Finance', Decimal('7800.00'), Decimal('22400.00')),
#  (110, 'Finance', Decimal('8200.00'), Decimal('30600.00')),
#  (109, 'Finance', Decimal('9000.00'), Decimal('39600.00')),
#  (108, 'Finance', Decimal('12000.00'), Decimal('51600.00')),
#  (107, 'IT', Decimal('4200.00'), Decimal('4200.00')),
#  (106, 'IT', Decimal('4800.00'), Decimal('13800.00')),
#  (105, 'IT', Decimal('4800.00'), Decimal('9000.00')),
#  (104, 'IT', Decimal('6000.00'), Decimal('19800.00')),
#  (103, 'IT', Decimal('9000.00'), Decimal('28800.00'))]

# %% [markdown]
# itversity solution

# %%
# %%sql
#
# SELECT e.employee_id,
#     d.department_name,
#     e.salary,
#     round(sum(e.salary) OVER (
#         PARTITION BY e.department_id
#         ORDER BY salary
#         ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW
#     ), 2) AS cum_salary_expense
# FROM employees AS e
#     JOIN departments AS d
#         ON e.department_id = d.department_id
#     WHERE d.department_name IN ('Finance', 'IT')
# ORDER BY d.department_name,
#     e.salary
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_hr_db
# 11 rows affected.
# [(113, 'Finance', Decimal('6900.00'), Decimal('6900.00')),
#  (111, 'Finance', Decimal('7700.00'), Decimal('14600.00')),
#  (112, 'Finance', Decimal('7800.00'), Decimal('22400.00')),
#  (110, 'Finance', Decimal('8200.00'), Decimal('30600.00')),
#  (109, 'Finance', Decimal('9000.00'), Decimal('39600.00')),
#  (108, 'Finance', Decimal('12000.00'), Decimal('51600.00')),
#  (107, 'IT', Decimal('4200.00'), Decimal('4200.00')),
#  (106, 'IT', Decimal('4800.00'), Decimal('13800.00')),
#  (105, 'IT', Decimal('4800.00'), Decimal('9000.00')),
#  (104, 'IT', Decimal('6000.00'), Decimal('19800.00')),
#  (103, 'IT', Decimal('9000.00'), Decimal('28800.00'))]

# %% [markdown]
# ### Problem 3

# %%
# %%sql
#
# SELECT t.* FROM (
#     SELECT employee_id, department_id, department_name, salary,
#     dense_rank() OVER (PARTITION BY e.department_id ORDER BY salary DESC) AS employee_rank
#     FROM employees e INNER JOIN departments d
#     USING(department_id)
# ) t WHERE t.employee_rank<=3 ORDER BY department_id, salary DESC
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_hr_db
# 26 rows affected.
# [(200, 10, 'Administration', Decimal('4400.00'), 1),
#  (201, 20, 'Marketing', Decimal('13000.00'), 1),
#  (202, 20, 'Marketing', Decimal('6000.00'), 2),
#  (114, 30, 'Purchasing', Decimal('11000.00'), 1),
#  (115, 30, 'Purchasing', Decimal('3100.00'), 2),
#  (116, 30, 'Purchasing', Decimal('2900.00'), 3),
#  (203, 40, 'Human Resources', Decimal('6500.00'), 1),
#  (121, 50, 'Shipping', Decimal('8200.00'), 1),
#  (120, 50, 'Shipping', Decimal('8000.00'), 2),
#  (122, 50, 'Shipping', Decimal('7900.00'), 3),
#  (103, 60, 'IT', Decimal('9000.00'), 1),
#  (104, 60, 'IT', Decimal('6000.00'), 2),
#  (105, 60, 'IT', Decimal('4800.00'), 3),
#  (106, 60, 'IT', Decimal('4800.00'), 3),
#  (204, 70, 'Public Relations', Decimal('10000.00'), 1),
#  (145, 80, 'Sales', Decimal('14000.00'), 1),
#  (146, 80, 'Sales', Decimal('13500.00'), 2),
#  (147, 80, 'Sales', Decimal('12000.00'), 3),
#  (100, 90, 'Executive', Decimal('24000.00'), 1),
#  (101, 90, 'Executive', Decimal('17000.00'), 2),
#  (102, 90, 'Executive', Decimal('17000.00'), 2),
#  (108, 100, 'Finance', Decimal('12000.00'), 1),
#  (109, 100, 'Finance', Decimal('9000.00'), 2),
#  (110, 100, 'Finance', Decimal('8200.00'), 3),
#  (205, 110, 'Accounting', Decimal('12000.00'), 1),
#  (206, 110, 'Accounting', Decimal('8300.00'), 2)]

# %% [markdown]
# itversity solution

# %%
# %%sql
#
# SELECT *
# FROM (
#     SELECT e.employee_id,
#         e.department_id,
#         d.department_name,
#         e.salary,
#         dense_rank() OVER (
#             PARTITION BY e.department_id
#             ORDER BY e.salary DESC
#         ) AS employee_rank
#     FROM employees AS e
#         JOIN departments AS d
#             ON e.department_id = d.department_id
# ) AS e
# WHERE e.employee_rank <= 3
# ORDER BY e.department_id,
#     e.salary DESC
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_hr_db
# 26 rows affected.
# [(200, 10, 'Administration', Decimal('4400.00'), 1),
#  (201, 20, 'Marketing', Decimal('13000.00'), 1),
#  (202, 20, 'Marketing', Decimal('6000.00'), 2),
#  (114, 30, 'Purchasing', Decimal('11000.00'), 1),
#  (115, 30, 'Purchasing', Decimal('3100.00'), 2),
#  (116, 30, 'Purchasing', Decimal('2900.00'), 3),
#  (203, 40, 'Human Resources', Decimal('6500.00'), 1),
#  (121, 50, 'Shipping', Decimal('8200.00'), 1),
#  (120, 50, 'Shipping', Decimal('8000.00'), 2),
#  (122, 50, 'Shipping', Decimal('7900.00'), 3),
#  (103, 60, 'IT', Decimal('9000.00'), 1),
#  (104, 60, 'IT', Decimal('6000.00'), 2),
#  (105, 60, 'IT', Decimal('4800.00'), 3),
#  (106, 60, 'IT', Decimal('4800.00'), 3),
#  (204, 70, 'Public Relations', Decimal('10000.00'), 1),
#  (145, 80, 'Sales', Decimal('14000.00'), 1),
#  (146, 80, 'Sales', Decimal('13500.00'), 2),
#  (147, 80, 'Sales', Decimal('12000.00'), 3),
#  (100, 90, 'Executive', Decimal('24000.00'), 1),
#  (101, 90, 'Executive', Decimal('17000.00'), 2),
#  (102, 90, 'Executive', Decimal('17000.00'), 2),
#  (108, 100, 'Finance', Decimal('12000.00'), 1),
#  (109, 100, 'Finance', Decimal('9000.00'), 2),
#  (110, 100, 'Finance', Decimal('8200.00'), 3),
#  (205, 110, 'Accounting', Decimal('12000.00'), 1),
#  (206, 110, 'Accounting', Decimal('8300.00'), 2)]

# %% [markdown]
# ### Problem 4

# %% [markdown]
# > use retail database so restart kernal

# %%
# %load_ext sql

# %%
# %env DATABASE_URL=postgresql://deepan:DB_PASSWORD@localhost:5432/itversity_retail_db
# Out:
# env: DATABASE_URL=postgresql://deepan:DB_PASSWORD@localhost:5432/itversity_retail_db

# %%
# %sql SELECT * FROM orders LIMIT 1;
# Out:
# 1 rows affected.
# [(1, datetime.datetime(2013, 7, 25, 0, 0), 11599, 'CLOSED')]

# %%
# %sql SELECT * FROM order_items LIMIT 1;
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# 1 rows affected.
# [(1, 1, 957, 1, 299.98, 299.98)]

# %%
# %%sql
#
# WITH product_revenue AS (
#     SELECT p.product_id, p.product_name,
#     round(sum(oi.order_item_subtotal)::numeric, 2) as revenue
#     FROM products p INNER JOIN order_items oi
#     ON p.product_id=oi.order_item_product_id
#     INNER JOIN orders o ON o.order_id=oi.order_item_order_id
#     WHERE to_char(order_date,'YYYYMM')='201401'
#     AND order_status in ('COMPLETE', 'CLOSED')
#     GROUP BY p.product_id, p.product_name
# )
# SELECT * FROM (
#     SELECT *, rank() OVER(ORDER BY revenue DESC) AS product_rank
#     FROM product_revenue
# ) q WHERE product_rank<=3 ORDER by revenue DESC
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# 3 rows affected.
# [(1004, 'Field & Stream Sportsman 16 Gun Fire Safe', Decimal('250787.46'), 1),
#  (365, 'Perfect Fitness Perfect Rip Deck', Decimal('151474.75'), 2),
#  (957, "Diamondback Women's Serene Classic Comfort Bi", Decimal('148190.12'), 3)]

# %% [markdown]
# ### Problem 5

# %%
# %%sql
#
# WITH product_revenue AS (
#     SELECT c.category_id,
#         c.category_name,
#         p.product_id,
#         p.product_name,
#         round(sum(oi.order_item_subtotal)::numeric, 2) AS revenue
#     FROM orders AS o
#         JOIN order_items oi
#             ON o.order_id = oi.order_item_order_id
#         JOIN products AS p
#             ON p.product_id = oi.order_item_product_id
#         JOIN categories AS c
#             ON c.category_id = p.product_category_id
#     WHERE to_char(o.order_date, 'yyyy-MM') = '2014-01'
#         AND o.order_status IN ('COMPLETE', 'CLOSED')
#         AND c.category_name IN ('Cardio Equipment', 'Strength Training')
#     GROUP BY c.category_id,
#         c.category_name,
#         p.product_id,
#         p.product_name
# ) SELECT * FROM (
#     SELECT pr.*,
#         dense_rank() OVER (
#             PARTITION BY category_id
#             ORDER BY revenue DESC
#         ) AS product_rank
#     FROM product_revenue AS pr
# ) AS q
# WHERE product_rank <= 3
# ORDER BY category_id,
#     revenue DESC
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# 5 rows affected.
# [(9, 'Cardio Equipment', 191, "Nike Men's Free 5.0+ Running Shoe", Decimal('132286.77'), 1),
#  (9, 'Cardio Equipment', 172, "Nike Women's Tempo Shorts", Decimal('870.00'), 2),
#  (10, 'Strength Training', 208, 'SOLE E35 Elliptical', Decimal('1999.99'), 1),
#  (10, 'Strength Training', 203, 'GoPro HERO3+ Black Edition Camera', Decimal('1199.97'), 2),
#  (10, 'Strength Training', 216, 'Yakima DoubleDown Ace Hitch Mount 4-Bike Rack', Decimal('189.00'), 3)]
