# %% [markdown]
# ## Indexes for Constraints
#
# Let us understand details related to indexes for constraints.
# * Constraints such as primary key and unique are supported by indexes.
# * **Primary Key** - Unique and Not Null.
# * **Unique** - Unique and can be null.
# * Unless data is sorted, we need to perform full table scan to enforce uniqueness. Almost all the databases will create indexes implicitly for Primary Keys as well as Unique constraints.
# * We cannot define Primary Key or Unique constraint with out associated index.
# * It is quite common that we explicitly create indexes on foreign key columns to improve the performance.

# %%
# %load_ext sql

# %%
# %env DATABASE_URL=postgresql://deepan:DB_PASSWORD@localhost:5432/itversity_retail_db
# Out:
# env: DATABASE_URL=postgresql://deepan:DB_PASSWORD@localhost:5432/itversity_retail_db

# %%
# %sql DROP TABLE IF EXISTS users
# Out:
# Done.
# []

# %%
# %sql DROP SEQUENCE IF EXISTS users_user_id_seq
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# Done.
# []

# %%
# %%sql
#
# CREATE TABLE users (
#     user_id INT,
#     user_first_name VARCHAR(30) NOT NULL,
#     user_last_name VARCHAR(30) NOT NULL,
#     user_email_id VARCHAR(50) NOT NULL,
#     user_email_validated BOOLEAN,
#     user_password VARCHAR(200),
#     user_role VARCHAR(1),
#     is_active BOOLEAN,
#     created_dt DATE DEFAULT CURRENT_DATE
# )
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# Done.
# []

# %%
# %%sql
#
# SELECT table_catalog,
#     table_name,
#     constraint_type,
#     constraint_name
# FROM information_schema.table_constraints
# WHERE table_name = 'users'
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# 3 rows affected.
# [('itversity_retail_db', 'users', 'CHECK', '2200_16692_2_not_null'),
#  ('itversity_retail_db', 'users', 'CHECK', '2200_16692_3_not_null'),
#  ('itversity_retail_db', 'users', 'CHECK', '2200_16692_4_not_null')]

# %%
# %%sql
#
# SELECT * FROM pg_catalog.pg_indexes
# WHERE schemaname = 'public'
#     AND tablename = 'users'
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# 0 rows affected.
# []

# %%
# %sql CREATE SEQUENCE users_user_id_seq
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# Done.
# []

# %%
# %%sql
#
# ALTER TABLE users
#     ALTER COLUMN user_id SET DEFAULT nextval('users_user_id_seq'),
#     ADD PRIMARY KEY (user_id)
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# Done.
# []

# %%
# %%sql
#
# SELECT table_catalog,
#     table_name,
#     constraint_type,
#     constraint_name
# FROM information_schema.table_constraints
# WHERE table_name = 'users'
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# 5 rows affected.
# [('itversity_retail_db', 'users', 'PRIMARY KEY', 'users_pkey'),
#  ('itversity_retail_db', 'users', 'CHECK', '2200_16692_1_not_null'),
#  ('itversity_retail_db', 'users', 'CHECK', '2200_16692_2_not_null'),
#  ('itversity_retail_db', 'users', 'CHECK', '2200_16692_3_not_null'),
#  ('itversity_retail_db', 'users', 'CHECK', '2200_16692_4_not_null')]

# %%
# %%sql
#
# SELECT * FROM pg_catalog.pg_indexes
# WHERE schemaname = 'public'
#     AND tablename = 'users'
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# 1 rows affected.
# [('public', 'users', 'users_pkey', None, 'CREATE UNIQUE INDEX users_pkey ON public.users USING btree (user_id)')]

# %%
# %%sql
#
# SELECT tc.table_catalog,
#     tc.table_name,
#     tc.constraint_name,
#     pi.indexname
# FROM information_schema.table_constraints tc JOIN pg_catalog.pg_indexes pi
#     ON tc.constraint_name = pi.indexname
# WHERE tc.table_schema = 'public'
#     AND tc.table_name = 'users'
#     AND tc.constraint_type = 'PRIMARY KEY'
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# 1 rows affected.
# [('itversity_retail_db', 'users', 'users_pkey', 'users_pkey')]

# %%
# %%sql
#
# ALTER TABLE users
#     ADD UNIQUE (user_email_id)
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# Done.
# []

# %%
# %%sql
#
# SELECT table_catalog,
#     table_name,
#     constraint_type,
#     constraint_name
# FROM information_schema.table_constraints
# WHERE table_name = 'users'
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# 6 rows affected.
# [('itversity_retail_db', 'users', 'PRIMARY KEY', 'users_pkey'),
#  ('itversity_retail_db', 'users', 'UNIQUE', 'users_user_email_id_key'),
#  ('itversity_retail_db', 'users', 'CHECK', '2200_16692_1_not_null'),
#  ('itversity_retail_db', 'users', 'CHECK', '2200_16692_2_not_null'),
#  ('itversity_retail_db', 'users', 'CHECK', '2200_16692_3_not_null'),
#  ('itversity_retail_db', 'users', 'CHECK', '2200_16692_4_not_null')]

# %%
# %%sql
#
# SELECT * FROM pg_catalog.pg_indexes
# WHERE schemaname = 'public'
#     AND tablename = 'users'
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# 2 rows affected.
# [('public', 'users', 'users_pkey', None, 'CREATE UNIQUE INDEX users_pkey ON public.users USING btree (user_id)'),
#  ('public', 'users', 'users_user_email_id_key', None, 'CREATE UNIQUE INDEX users_user_email_id_key ON public.users USING btree (user_email_id)')]

# %%
# %%sql
#
# SELECT tc.table_catalog,
#     tc.table_name,
#     tc.constraint_name,
#     pi.indexname
# FROM information_schema.table_constraints tc JOIN pg_catalog.pg_indexes pi
#     ON tc.constraint_name = pi.indexname
# WHERE tc.table_schema = 'public'
#     AND tc.table_name = 'users'
#     AND tc.constraint_type = 'UNIQUE'
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# 1 rows affected.
# [('itversity_retail_db', 'users', 'users_user_email_id_key', 'users_user_email_id_key')]

# %% [markdown]
# ```{note}
# Query to get all the primary key and unique constraints along with indexes.
# ```

# %%
# %%sql
#
# SELECT tc.table_catalog,
#     tc.table_name,
#     tc.constraint_type,
#     tc.constraint_name,
#     pi.indexname
# FROM information_schema.table_constraints tc JOIN pg_catalog.pg_indexes pi
#     ON tc.constraint_name = pi.indexname
# WHERE tc.table_catalog = 'itversity_retail_db'
#     AND tc.constraint_type IN ('PRIMARY KEY', 'UNIQUE')
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# 113 rows affected.
# [('itversity_retail_db', 'pg_proc', 'PRIMARY KEY', 'pg_proc_oid_index', 'pg_proc_oid_index'),
#  ('itversity_retail_db', 'pg_proc', 'UNIQUE', 'pg_proc_proname_args_nsp_index', 'pg_proc_proname_args_nsp_index'),
#  ('itversity_retail_db', 'pg_type', 'PRIMARY KEY', 'pg_type_oid_index', 'pg_type_oid_index'),
#  ('itversity_retail_db', 'pg_type', 'UNIQUE', 'pg_type_typname_nsp_index', 'pg_type_typname_nsp_index'),
#  ('itversity_retail_db', 'pg_attribute', 'UNIQUE', 'pg_attribute_relid_attnam_index', 'pg_attribute_relid_attnam_index'),
#  ('itversity_retail_db', 'pg_attribute', 'PRIMARY KEY', 'pg_attribute_relid_attnum_index', 'pg_attribute_relid_attnum_index'),
#  ('itversity_retail_db', 'pg_class', 'PRIMARY KEY', 'pg_class_oid_index', 'pg_class_oid_index'),
#  ('itversity_retail_db', 'pg_class', 'UNIQUE', 'pg_class_relname_nsp_index', 'pg_class_relname_nsp_index'),
#  ('itversity_retail_db', 'pg_attrdef', 'UNIQUE', 'pg_attrdef_adrelid_adnum_index', 'pg_attrdef_adrelid_adnum_index'),
#  ('itversity_retail_db', 'pg_attrdef', 'PRIMARY KEY', 'pg_attrdef_oid_index', 'pg_attrdef_oid_index'),
#  ('itversity_retail_db', 'pg_constraint', 'UNIQUE', 'pg_constraint_conrelid_contypid_conname_index', 'pg_constraint_conrelid_contypid_conname_index'),
#  ('itversity_retail_db', 'pg_constraint', 'PRIMARY KEY', 'pg_constraint_oid_index', 'pg_constraint_oid_index'),
#  ('itversity_retail_db', 'pg_inherits', 'PRIMARY KEY', 'pg_inherits_relid_seqno_index', 'pg_inherits_relid_seqno_index'),
#  ('itversity_retail_db', 'pg_index', 'PRIMARY KEY', 'pg_index_indexrelid_index', 'pg_index_indexrelid_index'),
#  ('itversity_retail_db', 'pg_operator', 'PRIMARY KEY', 'pg_operator_oid_index', 'pg_operator_oid_index'),
#  ('itversity_retail_db', 'pg_operator', 'UNIQUE', 'pg_operator_oprname_l_r_n_index', 'pg_operator_oprname_l_r_n_index'),
#  ('itversity_retail_db', 'pg_opfamily', 'UNIQUE', 'pg_opfamily_am_name_nsp_index', 'pg_opfamily_am_name_nsp_index'),
#  ('itversity_retail_db', 'pg_opfamily', 'PRIMARY KEY', 'pg_opfamily_oid_index', 'pg_opfamily_oid_index'),
#  ('itversity_retail_db', 'pg_opclass', 'UNIQUE', 'pg_opclass_am_name_nsp_index', 'pg_opclass_am_name_nsp_index'),
#  ('itversity_retail_db', 'pg_opclass', 'PRIMARY KEY', 'pg_opclass_oid_index', 'pg_opclass_oid_index'),
#  ('itversity_retail_db', 'pg_am', 'UNIQUE', 'pg_am_name_index', 'pg_am_name_index'),
#  ('itversity_retail_db', 'pg_am', 'PRIMARY KEY', 'pg_am_oid_index', 'pg_am_oid_index'),
#  ('itversity_retail_db', 'pg_amop', 'UNIQUE', 'pg_amop_fam_strat_index', 'pg_amop_fam_strat_index'),
#  ('itversity_retail_db', 'pg_amop', 'UNIQUE', 'pg_amop_opr_fam_index', 'pg_amop_opr_fam_index'),
#  ('itversity_retail_db', 'pg_amop', 'PRIMARY KEY', 'pg_amop_oid_index', 'pg_amop_oid_index'),
#  ('itversity_retail_db', 'pg_amproc', 'UNIQUE', 'pg_amproc_fam_proc_index', 'pg_amproc_fam_proc_index'),
#  ('itversity_retail_db', 'pg_amproc', 'PRIMARY KEY', 'pg_amproc_oid_index', 'pg_amproc_oid_index'),
#  ('itversity_retail_db', 'pg_language', 'UNIQUE', 'pg_language_name_index', 'pg_language_name_index'),
#  ('itversity_retail_db', 'pg_language', 'PRIMARY KEY', 'pg_language_oid_index', 'pg_language_oid_index'),
#  ('itversity_retail_db', 'pg_largeobject_metadata', 'PRIMARY KEY', 'pg_largeobject_metadata_oid_index', 'pg_largeobject_metadata_oid_index'),
#  ('itversity_retail_db', 'pg_largeobject', 'PRIMARY KEY', 'pg_largeobject_loid_pn_index', 'pg_largeobject_loid_pn_index'),
#  ('itversity_retail_db', 'pg_aggregate', 'PRIMARY KEY', 'pg_aggregate_fnoid_index', 'pg_aggregate_fnoid_index'),
#  ('itversity_retail_db', 'pg_statistic', 'PRIMARY KEY', 'pg_statistic_relid_att_inh_index', 'pg_statistic_relid_att_inh_index'),
#  ('itversity_retail_db', 'pg_statistic_ext', 'PRIMARY KEY', 'pg_statistic_ext_oid_index', 'pg_statistic_ext_oid_index'),
#  ('itversity_retail_db', 'pg_statistic_ext', 'UNIQUE', 'pg_statistic_ext_name_index', 'pg_statistic_ext_name_index'),
#  ('itversity_retail_db', 'pg_statistic_ext_data', 'PRIMARY KEY', 'pg_statistic_ext_data_stxoid_index', 'pg_statistic_ext_data_stxoid_index'),
#  ('itversity_retail_db', 'pg_rewrite', 'PRIMARY KEY', 'pg_rewrite_oid_index', 'pg_rewrite_oid_index'),
#  ('itversity_retail_db', 'pg_rewrite', 'UNIQUE', 'pg_rewrite_rel_rulename_index', 'pg_rewrite_rel_rulename_index'),
#  ('itversity_retail_db', 'pg_trigger', 'UNIQUE', 'pg_trigger_tgrelid_tgname_index', 'pg_trigger_tgrelid_tgname_index'),
#  ('itversity_retail_db', 'pg_trigger', 'PRIMARY KEY', 'pg_trigger_oid_index', 'pg_trigger_oid_index'),
#  ('itversity_retail_db', 'pg_event_trigger', 'UNIQUE', 'pg_event_trigger_evtname_index', 'pg_event_trigger_evtname_index'),
#  ('itversity_retail_db', 'pg_event_trigger', 'PRIMARY KEY', 'pg_event_trigger_oid_index', 'pg_event_trigger_oid_index'),
#  ('itversity_retail_db', 'pg_description', 'PRIMARY KEY', 'pg_description_o_c_o_index', 'pg_description_o_c_o_index'),
#  ('itversity_retail_db', 'pg_cast', 'PRIMARY KEY', 'pg_cast_oid_index', 'pg_cast_oid_index'),
#  ('itversity_retail_db', 'pg_cast', 'UNIQUE', 'pg_cast_source_target_index', 'pg_cast_source_target_index'),
#  ('itversity_retail_db', 'pg_enum', 'PRIMARY KEY', 'pg_enum_oid_index', 'pg_enum_oid_index'),
#  ('itversity_retail_db', 'pg_enum', 'UNIQUE', 'pg_enum_typid_label_index', 'pg_enum_typid_label_index'),
#  ('itversity_retail_db', 'pg_enum', 'UNIQUE', 'pg_enum_typid_sortorder_index', 'pg_enum_typid_sortorder_index'),
#  ('itversity_retail_db', 'pg_namespace', 'UNIQUE', 'pg_namespace_nspname_index', 'pg_namespace_nspname_index'),
#  ('itversity_retail_db', 'pg_namespace', 'PRIMARY KEY', 'pg_namespace_oid_index', 'pg_namespace_oid_index'),
#  ('itversity_retail_db', 'pg_conversion', 'UNIQUE', 'pg_conversion_default_index', 'pg_conversion_default_index'),
#  ('itversity_retail_db', 'pg_conversion', 'UNIQUE', 'pg_conversion_name_nsp_index', 'pg_conversion_name_nsp_index'),
#  ('itversity_retail_db', 'pg_conversion', 'PRIMARY KEY', 'pg_conversion_oid_index', 'pg_conversion_oid_index'),
#  ('itversity_retail_db', 'pg_database', 'UNIQUE', 'pg_database_datname_index', 'pg_database_datname_index'),
#  ('itversity_retail_db', 'pg_database', 'PRIMARY KEY', 'pg_database_oid_index', 'pg_database_oid_index'),
#  ('itversity_retail_db', 'pg_db_role_setting', 'PRIMARY KEY', 'pg_db_role_setting_databaseid_rol_index', 'pg_db_role_setting_databaseid_rol_index'),
#  ('itversity_retail_db', 'pg_tablespace', 'PRIMARY KEY', 'pg_tablespace_oid_index', 'pg_tablespace_oid_index'),
#  ('itversity_retail_db', 'pg_tablespace', 'UNIQUE', 'pg_tablespace_spcname_index', 'pg_tablespace_spcname_index'),
#  ('itversity_retail_db', 'pg_authid', 'UNIQUE', 'pg_authid_rolname_index', 'pg_authid_rolname_index'),
#  ('itversity_retail_db', 'pg_authid', 'PRIMARY KEY', 'pg_authid_oid_index', 'pg_authid_oid_index'),
#  ('itversity_retail_db', 'pg_auth_members', 'PRIMARY KEY', 'pg_auth_members_role_member_index', 'pg_auth_members_role_member_index'),
#  ('itversity_retail_db', 'pg_auth_members', 'UNIQUE', 'pg_auth_members_member_role_index', 'pg_auth_members_member_role_index'),
#  ('itversity_retail_db', 'pg_shdescription', 'PRIMARY KEY', 'pg_shdescription_o_c_index', 'pg_shdescription_o_c_index'),
#  ('itversity_retail_db', 'pg_ts_config', 'UNIQUE', 'pg_ts_config_cfgname_index', 'pg_ts_config_cfgname_index'),
#  ('itversity_retail_db', 'pg_ts_config', 'PRIMARY KEY', 'pg_ts_config_oid_index', 'pg_ts_config_oid_index'),
#  ('itversity_retail_db', 'pg_ts_config_map', 'PRIMARY KEY', 'pg_ts_config_map_index', 'pg_ts_config_map_index'),
#  ('itversity_retail_db', 'pg_ts_dict', 'UNIQUE', 'pg_ts_dict_dictname_index', 'pg_ts_dict_dictname_index'),
#  ('itversity_retail_db', 'pg_ts_dict', 'PRIMARY KEY', 'pg_ts_dict_oid_index', 'pg_ts_dict_oid_index'),
#  ('itversity_retail_db', 'pg_ts_parser', 'UNIQUE', 'pg_ts_parser_prsname_index', 'pg_ts_parser_prsname_index'),
#  ('itversity_retail_db', 'pg_ts_parser', 'PRIMARY KEY', 'pg_ts_parser_oid_index', 'pg_ts_parser_oid_index'),
#  ('itversity_retail_db', 'pg_ts_template', 'UNIQUE', 'pg_ts_template_tmplname_index', 'pg_ts_template_tmplname_index'),
#  ('itversity_retail_db', 'pg_ts_template', 'PRIMARY KEY', 'pg_ts_template_oid_index', 'pg_ts_template_oid_index'),
#  ('itversity_retail_db', 'pg_extension', 'PRIMARY KEY', 'pg_extension_oid_index', 'pg_extension_oid_index'),
#  ('itversity_retail_db', 'pg_extension', 'UNIQUE', 'pg_extension_name_index', 'pg_extension_name_index'),
#  ('itversity_retail_db', 'pg_foreign_data_wrapper', 'PRIMARY KEY', 'pg_foreign_data_wrapper_oid_index', 'pg_foreign_data_wrapper_oid_index'),
#  ('itversity_retail_db', 'pg_foreign_data_wrapper', 'UNIQUE', 'pg_foreign_data_wrapper_name_index', 'pg_foreign_data_wrapper_name_index'),
#  ('itversity_retail_db', 'pg_foreign_server', 'PRIMARY KEY', 'pg_foreign_server_oid_index', 'pg_foreign_server_oid_index'),
#  ('itversity_retail_db', 'pg_foreign_server', 'UNIQUE', 'pg_foreign_server_name_index', 'pg_foreign_server_name_index'),
#  ('itversity_retail_db', 'pg_user_mapping', 'PRIMARY KEY', 'pg_user_mapping_oid_index', 'pg_user_mapping_oid_index'),
#  ('itversity_retail_db', 'pg_user_mapping', 'UNIQUE', 'pg_user_mapping_user_server_index', 'pg_user_mapping_user_server_index'),
#  ('itversity_retail_db', 'pg_foreign_table', 'PRIMARY KEY', 'pg_foreign_table_relid_index', 'pg_foreign_table_relid_index'),
#  ('itversity_retail_db', 'pg_policy', 'PRIMARY KEY', 'pg_policy_oid_index', 'pg_policy_oid_index'),
#  ('itversity_retail_db', 'pg_policy', 'UNIQUE', 'pg_policy_polrelid_polname_index', 'pg_policy_polrelid_polname_index'),
#  ('itversity_retail_db', 'pg_replication_origin', 'PRIMARY KEY', 'pg_replication_origin_roiident_index', 'pg_replication_origin_roiident_index'),
#  ('itversity_retail_db', 'pg_replication_origin', 'UNIQUE', 'pg_replication_origin_roname_index', 'pg_replication_origin_roname_index'),
#  ('itversity_retail_db', 'pg_default_acl', 'UNIQUE', 'pg_default_acl_role_nsp_obj_index', 'pg_default_acl_role_nsp_obj_index'),
#  ('itversity_retail_db', 'pg_default_acl', 'PRIMARY KEY', 'pg_default_acl_oid_index', 'pg_default_acl_oid_index'),
#  ('itversity_retail_db', 'pg_init_privs', 'PRIMARY KEY', 'pg_init_privs_o_c_o_index', 'pg_init_privs_o_c_o_index'),
#  ('itversity_retail_db', 'pg_seclabel', 'PRIMARY KEY', 'pg_seclabel_object_index', 'pg_seclabel_object_index'),
#  ('itversity_retail_db', 'pg_shseclabel', 'PRIMARY KEY', 'pg_shseclabel_object_index', 'pg_shseclabel_object_index'),
#  ('itversity_retail_db', 'pg_collation', 'UNIQUE', 'pg_collation_name_enc_nsp_index', 'pg_collation_name_enc_nsp_index'),
#  ('itversity_retail_db', 'pg_collation', 'PRIMARY KEY', 'pg_collation_oid_index', 'pg_collation_oid_index'),
#  ('itversity_retail_db', 'pg_partitioned_table', 'PRIMARY KEY', 'pg_partitioned_table_partrelid_index', 'pg_partitioned_table_partrelid_index'),
#  ('itversity_retail_db', 'pg_range', 'PRIMARY KEY', 'pg_range_rngtypid_index', 'pg_range_rngtypid_index'),
#  ('itversity_retail_db', 'pg_range', 'UNIQUE', 'pg_range_rngmultitypid_index', 'pg_range_rngmultitypid_index'),
#  ('itversity_retail_db', 'pg_transform', 'PRIMARY KEY', 'pg_transform_oid_index', 'pg_transform_oid_index'),
#  ('itversity_retail_db', 'pg_transform', 'UNIQUE', 'pg_transform_type_lang_index', 'pg_transform_type_lang_index'),
#  ('itversity_retail_db', 'pg_sequence', 'PRIMARY KEY', 'pg_sequence_seqrelid_index', 'pg_sequence_seqrelid_index'),
#  ('itversity_retail_db', 'pg_publication', 'PRIMARY KEY', 'pg_publication_oid_index', 'pg_publication_oid_index'),
#  ('itversity_retail_db', 'pg_publication', 'UNIQUE', 'pg_publication_pubname_index', 'pg_publication_pubname_index'),
#  ('itversity_retail_db', 'pg_publication_rel', 'PRIMARY KEY', 'pg_publication_rel_oid_index', 'pg_publication_rel_oid_index'),
#  ('itversity_retail_db', 'pg_publication_rel', 'UNIQUE', 'pg_publication_rel_prrelid_prpubid_index', 'pg_publication_rel_prrelid_prpubid_index'),
#  ('itversity_retail_db', 'pg_subscription', 'PRIMARY KEY', 'pg_subscription_oid_index', 'pg_subscription_oid_index'),
#  ('itversity_retail_db', 'pg_subscription', 'UNIQUE', 'pg_subscription_subname_index', 'pg_subscription_subname_index'),
#  ('itversity_retail_db', 'pg_subscription_rel', 'PRIMARY KEY', 'pg_subscription_rel_srrelid_srsubid_index', 'pg_subscription_rel_srrelid_srsubid_index'),
#  ('itversity_retail_db', 'departments', 'PRIMARY KEY', 'departments_pkey', 'departments_pkey'),
#  ('itversity_retail_db', 'categories', 'PRIMARY KEY', 'categories_pkey', 'categories_pkey'),
#  ('itversity_retail_db', 'products', 'PRIMARY KEY', 'products_pkey', 'products_pkey'),
#  ('itversity_retail_db', 'customers', 'PRIMARY KEY', 'customers_pkey', 'customers_pkey'),
#  ('itversity_retail_db', 'orders', 'PRIMARY KEY', 'orders_pkey', 'orders_pkey'),
#  ('itversity_retail_db', 'order_items', 'PRIMARY KEY', 'order_items_pkey', 'order_items_pkey'),
#  ('itversity_retail_db', 'users', 'PRIMARY KEY', 'users_pkey', 'users_pkey'),
#  ('itversity_retail_db', 'users', 'UNIQUE', 'users_user_email_id_key', 'users_user_email_id_key')]

# %% [markdown]
# ```{error}
# It is not possible to drop the indexes that are automatically created to enforce primary key or unique constraints.
# ```

# %%
# %sql DROP INDEX users_user_email_id_key
# Out:
#  * postgresql://deepan:***@localhost:5432/itversity_retail_db
# ---------------------------------------------------------------------------
# DependentObjectsStillExist                Traceback (most recent call last)
# File d:\BIGDATA-LEARN\data-engineering-spark-main\.venv\lib\site-packages\sqlalchemy\engine\base.py:1799, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798     if not evt_handled:
# -> 1799         self.dialect.do_execute(
#    1800             cursor, statement, parameters, context
#    1801         )
#    1803 if self._has_events or self.engine._has_events:
#
# File d:\BIGDATA-LEARN\data-engineering-spark-main\.venv\lib\site-packages\sqlalchemy\engine\default.py:717, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     716 def do_execute(self, cursor, statement, parameters, context=None):
# --> 717     cursor.execute(statement, parameters)
#
# DependentObjectsStillExist: cannot drop index users_user_email_id_key because constraint users_user_email_id_key on table users requires it
# HINT:  You can drop constraint users_user_email_id_key on table users instead.
#
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# d:\BIGDATA-LEARN\data-engineering-spark-main\itversity-material\01-python-and-sql\04_creating_tables_and_indexes_using_postgresql\08_indexes_for_constraints.ipynb Cell 21 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/BIGDATA-LEARN/data-engineering-spark-main/itversity-material/01-python-and-sql/04_creating_tables_and_indexes_using_postgresql/08_indexes_for_constraints.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_line_magic('sql', 'DROP INDEX users_user_email_id_key')
#
# File d:\BIGDATA-LEARN\data-engineering-spark-main\.venv\lib\site-packages\IPython\core\interactiveshell.py:2305, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2303     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2304 with self.builtin_trap:
# -> 2305     result = fn(*args, **kwargs)
#    2306 return result
#
# File d:\BIGDATA-LEARN\data-engineering-spark-main\.venv\lib\site-packages\sql\magic.py:217, in SqlMagic.execute(self, line, cell, local_ns)
#     214     return
#     216 try:
# --> 217     result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     219     if (
#     220         result is not None
#     221         and not isinstance(result, str)
#    (...)
#     224         # Instead of returning values, set variables directly in the
#     225         # users namespace. Variable names given by column names
#     227         if self.autopandas:
#
# File d:\BIGDATA-LEARN\data-engineering-spark-main\.venv\lib\site-packages\sql\run.py:367, in run(conn, sql, config, user_namespace)
#     365 else:
#     366     txt = sqlalchemy.sql.text(statement)
# --> 367     result = conn.session.execute(txt, user_namespace)
#     368 _commit(conn=conn, config=config)
#     369 if result and config.feedback:
#
# File d:\BIGDATA-LEARN\data-engineering-spark-main\.venv\lib\site-packages\sqlalchemy\engine\base.py:1286, in Connection.execute(self, statement, *multiparams, **params)
#    1282     util.raise_(
#    1283         exc.ObjectNotExecutableError(statement), replace_context=err
#    1284     )
#    1285 else:
# -> 1286     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File d:\BIGDATA-LEARN\data-engineering-spark-main\.venv\lib\site-packages\sqlalchemy\sql\elements.py:325, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321 def _execute_on_connection(
#     322     self, connection, multiparams, params, execution_options, _force=False
#     323 ):
#     324     if _force or self.supports_execution:
# --> 325         return connection._execute_clauseelement(
#     326             self, multiparams, params, execution_options
#     327         )
#     328     else:
#     329         raise exc.ObjectNotExecutableError(self)
#
# File d:\BIGDATA-LEARN\data-engineering-spark-main\.venv\lib\site-packages\sqlalchemy\engine\base.py:1478, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1466 compiled_cache = execution_options.get(
#    1467     "compiled_cache", self.engine._compiled_cache
#    1468 )
#    1470 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1471     dialect=dialect,
#    1472     compiled_cache=compiled_cache,
#    (...)
#    1476     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1477 )
# -> 1478 ret = self._execute_context(
#    1479     dialect,
#    1480     dialect.execution_ctx_cls._init_compiled,
#    1481     compiled_sql,
#    1482     distilled_params,
#    1483     execution_options,
#    1484     compiled_sql,
#    1485     distilled_params,
#    1486     elem,
#    1487     extracted_params,
#    1488     cache_hit=cache_hit,
#    1489 )
#    1490 if has_events:
#    1491     self.dispatch.after_execute(
#    1492         self,
#    1493         elem,
#    (...)
#    1497         ret,
#    1498     )
#
# File d:\BIGDATA-LEARN\data-engineering-spark-main\.venv\lib\site-packages\sqlalchemy\engine\base.py:1842, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1839             branched.close()
#    1841 except BaseException as e:
# -> 1842     self._handle_dbapi_exception(
#    1843         e, statement, parameters, cursor, context
#    1844     )
#    1846 return result
#
# File d:\BIGDATA-LEARN\data-engineering-spark-main\.venv\lib\site-packages\sqlalchemy\engine\base.py:2023, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2021     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2022 elif should_wrap:
# -> 2023     util.raise_(
#    2024         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2025     )
#    2026 else:
#    2027     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File d:\BIGDATA-LEARN\data-engineering-spark-main\.venv\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File d:\BIGDATA-LEARN\data-engineering-spark-main\.venv\lib\site-packages\sqlalchemy\engine\base.py:1799, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1797                 break
#    1798     if not evt_handled:
# -> 1799         self.dialect.do_execute(
#    1800             cursor, statement, parameters, context
#    1801         )
#    1803 if self._has_events or self.engine._has_events:
#    1804     self.dispatch.after_cursor_execute(
#    1805         self,
#    1806         cursor,
#    (...)
#    1810         context.executemany,
#    1811     )
#
# File d:\BIGDATA-LEARN\data-engineering-spark-main\.venv\lib\site-packages\sqlalchemy\engine\default.py:717, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     716 def do_execute(self, cursor, statement, parameters, context=None):
# --> 717     cursor.execute(statement, parameters)
#
# InternalError: (psycopg2.errors.DependentObjectsStillExist) cannot drop index users_user_email_id_key because constraint users_user_email_id_key on table users requires it
# HINT:  You can drop constraint users_user_email_id_key on table users instead.
#
# [SQL: DROP INDEX users_user_email_id_key]
# (Background on this error at: https://sqlalche.me/e/14/2j85)
